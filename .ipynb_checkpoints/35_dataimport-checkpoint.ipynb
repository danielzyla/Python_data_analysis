# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
education=pd.read_csv('/home/daniel/Documents/Anaconda_files/Python_scripts/StackOverflowDeveloperSurvey.csv',
                     usecols=["FormalEducation"])

# %%
type(education)
# Out:
# pandas.core.frame.DataFrame

# %%
education.head()
# Out:
#                                      FormalEducation
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree

# %%
education=pd.read_csv('/home/daniel/Documents/Anaconda_files/Python_scripts/StackOverflowDeveloperSurvey.csv',
                     usecols=["FormalEducation"], squeeze=True)

# %%
type(education)
# Out:
# pandas.core.series.Series

# %%
education.tail(10)
# Out:
# 51382                                      Master's degree
# 51383               I never completed any formal education
# 51384                                    Bachelor's degree
# 51385                                      Master's degree
# 51386    Some college/university study without earning ...
# 51387                                    Bachelor's degree
# 51388                                      Master's degree
# 51389    Some college/university study without earning ...
# 51390                                    Bachelor's degree
# 51391                                    Bachelor's degree
# Name: FormalEducation, dtype: object

# %%
allinfo=pd.read_csv('/home/daniel/Documents/Anaconda_files/Python_scripts/StackOverflowDeveloperSurvey.csv')

# %%
countries=allinfo["Country"]

# %%
countries.head()
# Out:
# 0     United States
# 1    United Kingdom
# 2    United Kingdom
# 3     United States
# 4       Switzerland
# Name: Country, dtype: object

# %%
type(countries)
# Out:
# pandas.core.series.Series

# %%
filterOnlyUSA = countries=="United States"

# %%
filterOnlyUSA.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Country, dtype: bool

# %%
allinfo
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# 5               6                                            Student
# 6               7  Professional non-developer who sometimes write...
# 7               8                             Professional developer
# 8               9                             Professional developer
# 9              10                             Professional developer
# 10             11  Professional non-developer who sometimes write...
# 11             12                             Professional developer
# 12             13                Used to be a professional developer
# ...

# %%
education.where(filterOnlyUSA).dropna().head(10)
# Out:
# 0              Secondary school
# 3               Doctoral degree
# 6               Master's degree
# 10            Bachelor's degree
# 15    Primary/elementary school
# 17            Bachelor's degree
# 18            Bachelor's degree
# 25              Master's degree
# 27            Bachelor's degree
# 29            Bachelor's degree
# Name: FormalEducation, dtype: object
