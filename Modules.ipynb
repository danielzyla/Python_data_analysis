# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
# %matplotlib inline

# %%
pd.read_csv('/home/danielz/Documents/Python/Data Science: Analiza danych/course-files/pokemon.csv')
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
plt.plot([2,4,6,8,10,12,14], [1,3,5,7,9,11,13], 'b')

# %%
x=np.arange(1.,10.,0.2)

# %%
x
# Out:
# array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. , 3.2, 3.4,
#        3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8, 5. , 5.2, 5.4, 5.6, 5.8, 6. ,
#        6.2, 6.4, 6.6, 6.8, 7. , 7.2, 7.4, 7.6, 7.8, 8. , 8.2, 8.4, 8.6,
#        8.8, 9. , 9.2, 9.4, 9.6, 9.8])

# %%
plt.plot(x, x*2, 'bs', x, np.log10(x), 'yo', x, np.sin(x), 'ro')

# %%
x
# Out:
# array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. , 3.2, 3.4,
#        3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8, 5. , 5.2, 5.4, 5.6, 5.8, 6. ,
#        6.2, 6.4, 6.6, 6.8, 7. , 7.2, 7.4, 7.6, 7.8, 8. , 8.2, 8.4, 8.6,
#        8.8, 9. , 9.2, 9.4, 9.6, 9.8])

# %%
y=math.pow(x,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-379a4c923038> in <module>
# ----> 1 y=math.pow(x,3)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-8b878066137b> in <module>
# ----> 1 list(round(x,1))
#
# TypeError: type numpy.ndarray doesn't define __round__ method

# %%
a=0.2

# %%
math.pow(a,3)
# Out:
# 0.008000000000000002

# %%
y=np.log10(x)

# %%
y
# Out:
# array([0.        , 0.07918125, 0.14612804, 0.20411998, 0.25527251,
#        0.30103   , 0.34242268, 0.38021124, 0.41497335, 0.44715803,
#        0.47712125, 0.50514998, 0.53147892, 0.5563025 , 0.5797836 ,
#        0.60205999, 0.62324929, 0.64345268, 0.66275783, 0.68124124,
#        0.69897   , 0.71600334, 0.73239376, 0.74818803, 0.76342799,
#        0.77815125, 0.79239169, 0.80617997, 0.81954394, 0.83250891,
#        0.84509804, 0.8573325 , 0.86923172, 0.88081359, 0.8920946 ,
#        0.90308999, 0.91381385, 0.92427929, 0.93449845, 0.94448267,
#        0.95424251, 0.96378783, 0.97312785, 0.98227123, 0.99122608])
